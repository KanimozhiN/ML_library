# %%
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats

# %% [markdown]
# ### LINE PLOT

# %%
mon=np.arange(1,13)
gold_price=[34000,35000,36000,37000,40000,45000,45500,46000,47000,47500,48000,50000]
plt.plot(mon,gold_price,marker="*")
plt.title("Gold price trend")
plt.xlabel("month")
plt.ylabel("price")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mon=np.arange(1,13)
gold_price=[34000,35000,36000,37000,40000,45000,45500,46000,47000,47500,48000,50000]
plt.plot(mon,gold_price,marker="*")
plt.title("Gold price trend")
plt.xlabel("month")
plt.ylabel("price")
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = pd.read_csv("Automobile.csv")
fig, ax=plt.subplots(figsize=(6,4))
plt.style.use('ggplot')
df_price=df.groupby(['fuel_type','engine_size'])
df_price.mean()['horsepower'].unstack().plot(ax=ax)
plt.show()

# %%
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
  
data = [21, 16, 34, 28, 13, 41]
  

fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)
  
plt.show()

# %%
fig, ax=plt.subplots(2,2)
x=np.linspace(0,8,1000)
ax[0,0].plot(x,x**2,'g')
ax[0,0].title.set_text('Axis[0,0]')
ax[1,0].plot(x,x**3,'k')
ax[1,0].title.set_text('Axis[1,0]')
ax[0,1].plot(x,np.sin(x),'b')
ax[0,1].title.set_text('Axis[0,1]')
ax[1,1].plot(x,np.cos(x),'r')
ax[1,1].title.set_text('Axis[1,1]')
